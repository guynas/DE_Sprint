# %% [markdown]
# ### Libs import

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset

# %%
age = []
sex = []
bmi = []
children = []
smoker = []
region = []
charges = []

# %%
with open("./3_dataset.txt", "r") as file:
    for human in file.readlines():
        age.append(int(human.split(",")[0]))
        
        if human.split(",")[1] == "male":
            sex.append(1)
        else:
            sex.append(0)
        
        bmi.append(float(human.split(",")[2]))
        children.append(int(human.split(",")[3]))
        
        if human.split(",")[4] == "yes":
            smoker.append(1)
        else:
            smoker.append(0)

        if human.split(",")[5] == "northwest":
            region.append(0)
        elif human.split(",")[5] == "northeast":
            region.append(1)
        elif human.split(",")[5] == "southwest":
            region.append(2)
        elif human.split(",")[5] == "southeast":
            region.append(3)
        else:
            region.append(human.split(",")[5])

        charges.append(float(human.split(",")[6]))

# %%
age = np.array(age)
sex = np.array(sex)
bmi = np.array(bmi)
children = np.array(children)
smoker = np.array(smoker)
region = np.array(region)
charges = np.array(charges)

# %%
age.min(), age.max(), age.mean()
# Out:
# (18, 64, 38.37761194029851)

# %%
charges.min(), charges.max(), charges.mean()
# Out:
# (1131.5066, 62592.87309, 12899.874326014924)

# %% [markdown]
# ### Age to charges correlation

# %%
plt.scatter(charges, age)

# %%
plt.scatter(np.log(charges), age)

# %% [markdown]
# ### BMI to charges correlation

# %%
plt.scatter(charges, bmi)

# %% [markdown]
# ### Children to charges correlation

# %%
plt.scatter(charges, children)

# %% [markdown]
# ### Smoking to charges correlation

# %%
plt.bar(smoker, charges)
# Out:
# <BarContainer object of 670 artists>

# %% [markdown]
# ### Charges histogram

# %%
plt.hist(charges)
# Out:
# (array([278., 188.,  74.,  38.,  19.,  29.,  24.,  15.,   3.,   2.]),
#  array([ 1131.5066  ,  7277.643249, 13423.779898, 19569.916547,
#         25716.053196, 31862.189845, 38008.326494, 44154.463143,
#         50300.599792, 56446.736441, 62592.87309 ]),
#  <BarContainer object of 10 artists>)

# %%
age[age < 36].shape
# Out:
# (307,)

# %%
age[age > 36][age[age > 36] < 50].shape
# Out:
# (167,)

# %%
age[age > 55].shape
# Out:
# (94,)

# %%
plt.scatter(charges[age < 36], bmi[age < 36], label = "age < 36") 
plt.scatter(charges[age > 36][age[age > 36] < 50], bmi[age > 36][age[age > 36] < 50], label = "36 < age < 50")
plt.scatter(charges[age > 55], bmi[age > 55], label = "age > 55")
plt.legend()
plt.show()

# %% [markdown]
# ### BMI histogram

# %%
plt.hist(bmi)
# Out:
# (array([ 27.,  80., 129., 153., 142.,  79.,  44.,  11.,   3.,   2.]),
#  array([16.815 , 20.4465, 24.078 , 27.7095, 31.341 , 34.9725, 38.604 ,
#         42.2355, 45.867 , 49.4985, 53.13  ]),
#  <BarContainer object of 10 artists>)

# %%
bmi[bmi < 21].shape
# Out:
# (32,)

# %%
bmi[bmi > 20][bmi[bmi > 20] < 38].shape
# Out:
# (582,)

# %%
bmi[bmi > 37].shape
# Out:
# (88,)

# %%
plt.scatter(charges[bmi < 21], bmi[bmi < 21], label = "bmi < 21") 
plt.scatter(charges[bmi > 20][bmi[bmi > 20] < 38], bmi[bmi > 20][bmi[bmi > 20] < 38], label = "20 < bmi < 38")
plt.scatter(charges[bmi > 37], bmi[bmi > 37], label = "bmi > 37")
plt.legend()
plt.show()
