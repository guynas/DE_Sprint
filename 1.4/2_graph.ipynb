# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-2, 2, 0.001)
y1 = ((x**2)**(1/3)+np.sqrt((x**4)**(1/3)-4*(x**2-1)))/2
y2 = ((x**2)**(1/3)-np.sqrt((x**4)**(1/3)-4*(x**2-1)))/2
plt.grid()
plt.plot(x, y1, color='red')
plt.plot(x, y2, color='red')
# Out:
# /tmp/ipykernel_42227/874275961.py:2: RuntimeWarning: invalid value encountered in sqrt
#   y1 = ((x**2)**(1/3)+np.sqrt((x**4)**(1/3)-4*(x**2-1)))/2
# /tmp/ipykernel_42227/874275961.py:3: RuntimeWarning: invalid value encountered in sqrt
#   y2 = ((x**2)**(1/3)-np.sqrt((x**4)**(1/3)-4*(x**2-1)))/2
